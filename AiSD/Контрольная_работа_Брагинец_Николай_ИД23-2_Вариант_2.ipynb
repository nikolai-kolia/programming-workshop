# %% [markdown]
# ### Контрольная работа № 1.
# ### Вариант 2.
# #### Студент Брагинец Николай группа ИД23-2

# %% [markdown]
# 1. Напишите программу, которая выполняет добавление, удаление и вывод на экран элементов списка при помощи классов.
#
# Решение задачи
#
# 1.	Создаем класс и с помощью конструктора инициализируем значения этого класса.
# 2.	Создаем в данном классе методы для добавления, удаления и вывода на экран соответствующих значений.
# 3.	Создаем объект данного класса.
# 4.	Используя созданный объект, вызываем соответствующий метод (в зависимости от выбора пользователя).
# 5.	Выводим результат на экран.
# 6.	Конец.
#
# В программе реализовать выбор с помощью меню:
#
# print("0. Выход")
#
# print("1. Добавить")
#
# print("2. Удалить")
#
# print("3. Вывести на экран")
#
# choice = int(input("Выберите одно из этих значений: "))

# %%
# Решение 1.

class new_list(object):
    def __init__(self):
        self.data = []
    
    def add_item(self):
        print('Введите значение, которое хотите добавить в список: ')
        self.data.append(input())
    
    def del_item(self):
        print('Введите индекс элемента, который хотите удалить: ')
        index=int(input())
        try:
            self.data.pop(index)
        except IndexError:
            print('В списке нет элемента с индексом {index}')
            
    def print_list(self):
        print(self.data)

a = new_list()
        
def activator(i):
    global a
    if i==1:
        print(1)
        a.add_item()
    elif i==2:
        print(2)
        a.del_item()
    elif i==3:
        print(3)
        a.print_list()

choice = 4
while choice!=0:
    print("0. Выход")
    print("1. Добавить")
    print("2. Удалить")
    print("3. Вывести на экран")
    choice = int(input("Выберите одно из этих значений: "))
    activator(choice)
# Out:
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 1
# 1
# Введите значение, которое хотите добавить в список:
# 23231
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 1
# 1
# Введите значение, которое хотите добавить в список:
# 23134324
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 3
# 3
# ['23231', '23134324']
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 0

# %% [markdown]
# 2. Используя класс People в качестве базового, создайте класс Сотрудник (Worker), имеющий свойства:
#
# • должность (post)
#
# • зарплата (salary)
#
# методы:
#
# • __init__ – конструктор;
#
# • __str__ – аналогично методу класса Teacher из примера.
#
# Используя класс Сотрудник в качестве базового создайте класс Преподаватель (Teacher), имеющий:
#
# • закрытый атрибут дисциплины (disciplines), в котором хранятся названия дисциплин, которые ведет преподаватель;
#
# • методы __init__ и __str__;
#
# • методы добавить_дисциплину (add_dis) и удалить_дисциплину (delete_dis), которые позволяют изменять список дисциплин.
#
# Создайте список, содержащий по 2 объекта каждого класса (People, Worker, Teacher). Для этого списка:
#
# • выведите информацию о каждом человеке с помощью метода info;
#
# • выведите фамилии тех, кто моложе 30 лет;
#
# • продемонстрируйте работу со свойствами должность и зарплата и методами добавить_дисциплину и удалить_дисциплину.

# %%
# Решение 2.
class People():
    def __init__(self, name, surname, age):
        self.name=name
        self.surname=surname
        self.age=age
        self.info_dict={'Name': self.name, 'Surname': self.surname, 'Age': self.age}
        
    def info(self):
        for i, j in self.info_dict.items():
            print(i, ': ', j)
    
    def __str__(self):
        return str(info_dict)
    
class Worker(People):
    def __init__(self, name, surname, age, post, salary):
        super().__init__(name, surname, age)
        self.post=post
        self.salary=salary
        self.info_dict={'Name': self.name, 'Surname': self.surname, 'Age': self.age, 'Post': self.post, 'Salary': self.salary}
        
    def info(self):
        for i, j in self.info_dict.items():
            print(i, ': ', j)
       
    def __str__(self):
        return str(info_dict)
    
class Teacher(Worker):
    def __init__(self, name, surname, age, post, salary, disciplines):
        super().__init__(name, surname, age, post, salary)
        self.__disciplines=disciplines
        self.info_dict={'Name': self.name, 'Surname': self.surname, 'Age': self.age, 'Post': self.post, 'Salary': self.salary, 'Disciplines': self.__disciplines}
        
    def info(self):
        for i, j in self.info_dict.items():
            print(i, ': ', j)
       
    def __str__(self):
        return str(info_dict)
    
    @property
    def disciplines(self):
        return self.__disciplines
    
    @disciplines.setter
    def add_dis(self, discipline1):
        self.__disciplines.append(discipline1)
    
    @disciplines.setter
    def del_dis(self, discipline1):
        self.__disciplines.remove(discipline1)

p1=People('April', "O'Neil", 17)
p2=People('Casey', "Jones", 18)
w1=Worker('Sto', 'Shagov', 38, 'Singer', 200000)
w2=Worker('Le', 'Suan Bach', 19, 'Businessman', 5000000)
t1=Teacher('Eugine', 'Kublik', 32, 'Teacher', 120000, ['OVS'])
t2=Teacher('Vasiliy', 'Pupkin', 21, 'Teacher', 14000, ['PE', 'OBG'])

p_list=[p1, p2, w1, w2, t1, t2]
for i in p_list:
    i.info()
    print()
print('Список фамилий тех, кто моложе 30-ти: ', end='')
s_list=[]
for i in p_list:
    if i.age<30:
        s_list.append(i.surname)
print(', '.join(s_list))
print()
for i in p_list:
    try:
        print('Должность: ', i.post)
        print('Зарплата: ', i.salary)
        print('Фамилия: ', i.surname)
        print()
    except AttributeError:
        continue
# Out:
# Name :  April
# Surname :  O'Neil
# Age :  17
#
# Name :  Casey
# Surname :  Jones
# Age :  18
#
# Name :  Sto
# Surname :  Shagov
# Age :  38
# Post :  Singer
# Salary :  200000
#
# Name :  Le
# Surname :  Suan Bach
# Age :  19
# Post :  Businessman
# Salary :  5000000
#
# Name :  Eugine
# Surname :  Kublik
# Age :  32
# Post :  Teacher
# Salary :  120000
# Disciplines :  ['OVS']
#
# Name :  Vasiliy
# Surname :  Pupkin
# Age :  21
# Post :  Teacher
# Salary :  14000
# Disciplines :  ['PE', 'OBG']
#
# Список фамилий тех, кто моложе 30-ти: O'Neil, Jones, Suan Bach, Pupkin
#
# Должность:  Singer
# Зарплата:  200000
# Фамилия:  Shagov
#
# Должность:  Businessman
# Зарплата:  5000000
# Фамилия:  Suan Bach
#
# Должность:  Teacher
# Зарплата:  120000
# Фамилия:  Kublik
#
# Должность:  Teacher
# Зарплата:  14000
# Фамилия:  Pupkin

# %% [markdown]
# 3.Создайте класс Заказ(Order), у которого есть свойства кодтовара(code), цена(price), количество(count) и методы _init и str.
#
# Создайте 2 класса-потомка: Опт(Opt) и Розница(Retail). В этих классах создайте методы init, str.и сумма_заказа(summa), позволяющий узнать стоимость заказа. Для опта стоимость единицы товара составляет 95% от цены, а при покупке более 500 штук – 90% цены. В розницу стоимость единицы товара составляет 100% цены. Стоимость заказа равна произведению цены на количество.
#
# Продемонстрируйте работу с классами, создав необходимые объекты и обратившись к их свойствам и методам

# %%
# Решение 3.
class Order():
    def __init__(self, code, price, count):
        self.code=code
        self.price=price
        self.count=count
        self.sum=int(self.count)*int(self.price)
    
    def __str__(self):
        return f'Code: {self.code}, Price: {self.price}, Count: {self.count}'

class Opt(Order):
    def __init__(self, code, price, count):
        super().__init__(code, price, count)
    
    def summa(self):
        if self.count>500:
            return self.sum*0.9
        else:
            return self.sum*0.95

class Retail(Order):
    def __init__(self, code, price, count):
        super().__init__(code, price, count)
    
    def summa(self):
        return self.count*self.price

o1=Opt(1245, 330, 100)
o2=Opt(1245, 330, 1000)
r1=Retail(1245, 330, 4)
print(f'Цена: {o1.price}', f'Кол-во: {o1.count}', f'Сумма: {o1.summa()}', sep='\n', end='\n\n')
print(f'Цена: {o2.price}', f'Кол-во: {o2.count}', f'Сумма: {o2.summa()}', sep='\n', end='\n\n')
print(f'Цена: {r1.price}', f'Кол-во: {r1.count}', f'Сумма: {r1.summa()}', sep='\n')
# Out:
# Цена: 330
# Кол-во: 100
# Сумма: 31350.0
#
# Цена: 330
# Кол-во: 1000
# Сумма: 297000.0
#
# Цена: 330
# Кол-во: 4
# Сумма: 1320

# %% [markdown]
# 4.Написать функцию-генератор my_func_2(lst), которая принимает объект, поддерживающий итерации с произвольным уровнем вложенности, и возвращает все элементы по одному.

# %%
# Решение 4.
def my_func_2(lst):
    if isinstance(lst, (list, tuple, set)):
        for item in lst:
            yield from my_func_2(item)
    elif isinstance(lst, dict):
        for value in lst.values():
            yield from my_func_2(value)
    else:
        yield lst

list1 = [12, [132, 323, 12, 425], [123, [123, 313]], [321, [21, [123, 123]], 132], 1231, 13]
for i in my_func_2(list1):
    print(i)
# Out:
# 12
# 132
# 323
# 12
# 425
# 123
# 123
# 313
# 321
# 21
# 123
# 123
# 132
# 1231
# 13

# %% [markdown]
# 5.С помощью механизма map/filter/reduce (хотя бы одна из этих функций должна быть использована в решении) посчитать в тексте количество слов, состоящих не менее, чем из 3-х букв. Слова в тексте разделены пробелами. Написать реализацию в одну строку. Оформить решение в виде функции my_func_3(text), т.е. шаблон таков:
#
# строка с import, если необходимо def my_func_3(text): return # однострочная реализация задания

# %%
# Решение 5.
def my_func_3(text): return len(list(filter(lambda x: len(x)>=3, text.split())))
print(my_func_3(input()))
# Out:
# ыфаафыва выафвыа выаыв фвыв вывы выы вп
# 6
